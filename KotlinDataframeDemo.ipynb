// %%
%use dataframe(0.9.1)
// @file:DependsOn("E:\\Presentations\\dependencies\\dataframe-0.9.1.jar")
// @file:DependsOn("E:\\Presentations\\dependencies\\commons-csv-1.10.0.jar")
import java.time.LocalDate
import java.time.format.DateTimeFormatter
import kotlinx.datetime.LocalDate as KDate
import org.apache.commons.csv.CSVFormat
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>

// %%
val csvpath : String = "E:\\Presentations\\KotlinConfDataframe\\assets2\\data\\"

val dfCalendars = DataFrame.readCSV("${csvpath}calendars.csv", delimiter = ';')
val dfHotelOffers = DataFrame.readCSV("${csvpath}hoteloffers.csv", delimiter = ';')
val dfTierOffers = DataFrame.readCSV("${csvpath}tierofferssimple.csv", delimiter = ';')
val dfPlayers = DataFrame.readCSV("${csvpath}players.csv", delimiter = ';')
val dfMessages = DataFrame.readCSV("${csvpath}msg.csv", delimiter = ';')
val dfTiers = DataFrame.readCSV("${csvpath}tierdefinitionssimple.csv", delimiter = ';')

// %%
dfTiers
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944384"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 16, columnsCount = 6</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Tier: Int\">Tier</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>"] },
// { name: "<span title=\"MinValue: Double\">MinValue</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1250.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">750.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">400.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">125.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">80.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">25.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4000.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2000.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">800.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">400.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">250.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">75.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">25.0</span></span>"] },
// { name: "<span title=\"MaxValue: Double\">MaxValue</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">9999999.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1250.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">750.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">400.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">125.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">80.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9999999.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4000.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2000.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">800.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">400.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">250.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150.0</s

// %%
dfMessages
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944383"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 8, columnsCount = 6</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Category: String\">Category</span>", children: [], rightAlign: false, values: ["gaming","dining","totals","totals","gaming","dining","gaming","dining"] },
// { name: "<span title=\"Placement: String\">Placement</span>", children: [], rightAlign: false, values: ["GamingSubhead","DiningSubhead","OutsideHeadline","OutsideHeadline","GamingSubhead","DiningSubhead","GamingHeadline","DiningHeadline"] },
// { name: "<span title=\"TierMin: Int\">TierMin</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>"] },
// { name: "<span title=\"TierMax: Int\">TierMax</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2199</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2199</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1199</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2199</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1199</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1199</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9999</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9999</span></span>"] },
// { name: "<span title=\"Message: String\">Message</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Enjoy ~~ per visit at our 9 fantastic restaurants!\">Enjoy ~~ per visit at our 9 fantastic<span class=\"structural\">...</span></span>","10 ## OFFERS WORTH ^^ INSIDE!","GET UP TO ^^ WHEN YOU VISIT US IN ##!","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up to 10 times in ## and start <span class=\"structural\">...</span></span>","~~ on us, available once per week.","@@ in **","@@ Complimentary Dining"] },
// ], id: -1660944383, rootId: -1660944383, totalRows: 8 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1660944383) });
//
//
//         </script>
//         </html>

// %%
// dfMessages provides a TierMin & TierMax
// with explode(), we can create a row for every individual tier in the range
// then we can innerJoin with dfTiers, now every Message is matched with each of the corresponding tiers
val dfMsgTiers = dfMessages
    .remove { Category }
    .add("Tier") { (TierMin..TierMax).toList() }
    .explode("Tier")
    .innerJoin(dfTiers) { "Tier"<Int>() match(right.Tier) }
    .remove { "OfferMonth1" and TierMin and TierMax }
    .move("Tier").after { OfferMonth }

// %%
dfMsgTiers
    .filter { Tier == 2003 }
    .sortBy { Placement and Tier }
    
    
    //.sortBy { Placement and Tier }
    
    
    // .sortBy { Placement and Tier }
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944382"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 8</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Tier: Int\">Tier</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2003</span></span>"] },
// { name: "<span title=\"Placement: String\">Placement</span>", children: [], rightAlign: false, values: ["DiningHeadline","DiningSubhead","GamingHeadline","GamingSubhead","OutsideHeadline"] },
// { name: "<span title=\"Message: String\">Message</span>", children: [], rightAlign: false, values: ["@@ Complimentary Dining","<span class=\"formatted\" title=\"Enjoy ~~ per visit at our 9 fantastic restaurants!\">Enjoy ~~ per visit at our 9 fantastic<span class=\"structural\">...</span></span>","@@ in **","<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","GET UP TO ^^ WHEN YOU VISIT US IN ##!"] },
// { name: "<span title=\"MinValue: Double\">MinValue</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">800.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">800.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">800.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">800.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">800.0</span></span>"] },
// { name: "<span title=\"MaxValue: Double\">MaxValue</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2000.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2000.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2000.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2000.0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2000.0</span></span>"] },
// { name: "<span title=\"Measure: String\">Measure</span>", children: [], rightAlign: false, values: ["ADT","ADT","ADT","ADT","ADT"] },
// { name: "<span title=\"Geo: String\">Geo</span>", children: [], rightAlign: false, values: ["California","California","California","California","California"] },
// ], id: -1660944382, rootId: -1660944382, totalRows: 5 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1660944382) });
//
//
//         </script>
//         </html>

// %%
val dfMsgPivot = dfMsgTiers
    .groupBy { OfferMonth and Tier }
        .pivot { Placement }
            .with { Message }
    .flatten()
    
dfMsgPivot
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944381"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 16, columnsCount = 7</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Tier: Int\">Tier</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>"] },
// { name: "<span title=\"GamingSubhead: String\">GamingSubhead</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Start with ~~ to play your favorite games, twice in ##!\">Start with ~~ to play your favorite g<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up to 10 times in ## and start <span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up to 10 times in ## and start <span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up to 10 times in ## and start <span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up to 10 times in ## and start <span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up to 10 times in ## and start <span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up to 10 times in ## and start <span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up to 10 times in ## and start <span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Visit up to 10 times in ## and start with ~~.\">Visit up

// %%
dfTierOffers
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944380"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 16, columnsCount = 10</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Tier: Int\">Tier</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>"] },
// { name: "<span title=\"SlotAmount: Int\">SlotAmount</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">400</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">100</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">40</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">30</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">20</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">300</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">100</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">60</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">30</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>"] },
// { name: "<span title=\"TableAmount: Int\">TableAmount</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">300</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">75</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">45</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">30</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">30</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">20</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">750</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">400</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">125</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">75</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">35</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">20<

// %%
val GamePref by column<String>()
val GamingAmount by column<Int>()

val dfTierOffersByGame = dfTierOffers
    .add(GamePref) { listOf("Slot", "Table") }
    .explode { GamePref }
    .add(GamingAmount) { if (GamePref() == "Slot") SlotAmount else TableAmount }
    .update { TableType }.with { if (GamePref() == "Slot") "Slot Credits" else it }
    .rename { TableType }.into("GamingType")
    .move { GamePref and GamingAmount }.after { Tier }
    .remove { SlotAmount and TableAmount }
    
dfTierOffersByGame
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944379"></table>
//
// <p class="dataframe_description">... showing only top 20 of 32 rows</p><p class="dataframe_description">DataFrame: rowsCount = 32, columnsCount = 10</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Tier: Int\">Tier</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>"] },
// { name: "<span title=\"GamePref: String\">GamePref</span>", children: [], rightAlign: false, values: ["Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table"] },
// { name: "<span title=\"GamingAmount: Int\">GamingAmount</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">400</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">300</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">100</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">75</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">45</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">40</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">30</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">30</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">30</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">20</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">20</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">750</span></span>"] },
// { name: "<span title=\"GamingType: String\">GamingType</span>", children: [], rightAlign: false, values: ["Slot Credits","Bonus Chips","Slot Credits","Bonus Chips","Slot Credits","Bonus Chips","Slot Credits","Bonus Chips","Slot Credits","Bonus Chips","Slot Credits","Matched Bet","Slot Credits","Matched Bet","Slot Credits","Matched Bet","Slot

// %%
val dfTieredOffersPlusHotel = dfTierOffersByGame
    .leftJoin(dfMsgPivot) { OfferMonth and Tier }
    .leftJoin(dfHotelOffers) { OfferMonth and HotelCode }
    .update("GamingHeadline", "GamingSubhead").with { 
        it.toString()
            .replace("~~", GamingAmount.let{ g -> "\$${"%,d".format(g)}" })
            .replace("@@", GamingAmount.times(GamingFrequency).let{ g ->"\$${"%,d".format(g)}" })
            .replace("**", GamingType)
            .replace("##", LocalDate.parse(OfferMonth.toString()).format(DateTimeFormatter.ofPattern("MMMM")))
    }.update("DiningHeadline", "DiningSubhead").with { 
        it.toString()
            .replace("~~", DiningAmount.let {d -> "\$${"%,d".format(d)}" })
            .replace("@@", DiningAmount.times(DiningFrequency).let{ d ->"\$${"%,d".format(d)}" })
            .replace("##", LocalDate.parse(OfferMonth.toString()).format(DateTimeFormatter.ofPattern("MMMM")))
    }.update("OutsideHeadline").with { 
        it.toString()
            .replace("##", LocalDate.parse(OfferMonth.toString()).format(DateTimeFormatter.ofPattern("MMMM")).uppercase())
            .replace("^^", (GamingAmount.times(GamingFrequency)).plus(DiningAmount.times(DiningFrequency)).let{ t ->"\$${"%,d".format(t)}" })
    }
    .move("GamePref", "OutsideHeadline", "HotelHeadline", "HotelDescription", "HotelCode", 
             "GamingHeadline", "GamingSubhead", "DiningHeadline", "DiningSubhead").after { Tier }

    
dfTieredOffersPlusHotel
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944378"></table>
//
// <p class="dataframe_description">... showing only top 20 of 32 rows</p><p class="dataframe_description">DataFrame: rowsCount = 32, columnsCount = 17</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Tier: Int\">Tier</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>"] },
// { name: "<span title=\"GamePref: String\">GamePref</span>", children: [], rightAlign: false, values: ["Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table"] },
// { name: "<span title=\"OutsideHeadline: String\">OutsideHeadline</span>", children: [], rightAlign: false, values: ["10 JUNE OFFERS WORTH $4,400 INSIDE!","10 JUNE OFFERS WORTH $3,400 INSIDE!","10 JUNE OFFERS WORTH $2,240 INSIDE!","10 JUNE OFFERS WORTH $1,740 INSIDE!","10 JUNE OFFERS WORTH $1,160 INSIDE!","10 JUNE OFFERS WORTH $910 INSIDE!","10 JUNE OFFERS WORTH $620 INSIDE!","10 JUNE OFFERS WORTH $570 INSIDE!","10 JUNE OFFERS WORTH $480 INSIDE!","10 JUNE OFFERS WORTH $380 INSIDE!","10 JUNE OFFERS WORTH $360 INSIDE!","10 JUNE OFFERS WORTH $360 INSIDE!","10 JUNE OFFERS WORTH $240 INSIDE!","10 JUNE OFFERS WORTH $240 INSIDE!","10 JUNE OFFERS WORTH $178 INSIDE!","10 JUNE OFFERS WORTH $128 INSIDE!","<span class=\"formatted\" title=\"GET UP TO $2,800 WHEN YOU VISIT US IN JUNE!\">GET UP TO $2,800 WHEN YOU VISIT US IN<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"GET UP TO $3,600 WHEN YOU VISIT US IN JUNE!\">GET UP TO $3,600 WHEN YOU VISIT US IN<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"GET UP TO $1,500 WHEN YOU VISIT US IN JUNE!\">GET UP TO $1,500 WHEN YOU VISIT US IN<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"GET UP TO $1,800 WHEN YOU VISIT US IN JUNE!\">GET UP TO $1,800 WHEN YOU VISIT US IN<span class=\"structural\">...</span></span>"] },
// { name: "<span title=\"HotelHeadline: String\">HotelHeadline</span>", children: [], rightAlign: false, values: ["2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","1 NIGHT STAY-CATION","1 NIGHT STAY-CATION","1 NIGHT STAY-CATION","1 NIGHT STAY-CATION","RATES STARTING AT $39","RATES STARTING AT $39","RATES STARTING AT $39","RATES STARTING AT $39","3 NIGHTS IN A SUITE","3 NIGHTS IN A SUITE","3 NIGHTS IN A SUITE","3 NIGHTS IN A SUITE"] },
// { name: "<span title=\"HotelDescription: String\">HotelDescription</span>", children: [], rightAlign: false, values: ["<span class=\"form

// %%
dfTierOffersByGame.describe()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944377"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 10, columnsCount = 12</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"name: String\">name</span>", children: [], rightAlign: false, values: ["OfferMonth","Tier","GamePref","GamingAmount","GamingType","GamingFrequency","DiningAmount","DiningFrequency","HotelCode","HotelFrequency"] },
// { name: "<span title=\"type: Any\">type</span>", children: [], rightAlign: false, values: ["LocalDate","Int","String","Int","String","Int","Int","Int","String","Int"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>"] },
// { name: "<span title=\"unique: Int\">unique</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">20</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>"] },
// { name: "<span title=\"nulls: Int\">nulls</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"top: Comparable\">top</span>", children: [], rightAlign: false, values: ["2023-06-01","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","Slot","<span class=\"formatted\" title=\"\"><span class=\"numbers\">30</span></span>","Slot Credits","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">40</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","LV6231","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>"] },
// { name: "<span title=\"freq: Int\">freq</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">32</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<s

// %%
dfCalendars
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944376"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 18, columnsCount = 5</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"CalendarName: String\">CalendarName</span>", children: [], rightAlign: false, values: ["HotelCalendar","HotelCalendar","GamingCalendar","GamingCalendar","GamingCalendar","GamingCalendar","GamingCalendar","GamingCalendar","GamingCalendar","GamingCalendar","GamingCalendar","GamingCalendar","DiningCalendar","DiningCalendar","DiningCalendar","DiningCalendar","CalGeoAllCalendar","CalGeoAllCalendar"] },
// { name: "<span title=\"Period: Int\">Period</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>"] },
// { name: "<span title=\"StartDate: kotlinx.datetime.LocalDate\">StartDate</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-16","2023-06-01","2023-06-04","2023-06-07","2023-06-10","2023-06-13","2023-06-16","2023-06-19","2023-06-22","2023-06-25","2023-06-28","2023-06-01","2023-06-09","2023-06-16","2023-06-23","2023-06-01","2023-06-16"] },
// { name: "<span title=\"EndDate: kotlinx.datetime.LocalDate\">EndDate</span>", children: [], rightAlign: false, values: ["2023-06-15","2023-06-30","2023-06-03","2023-06-06","2023-06-09","2023-06-12","2023-06-15","2023-06-18","2023-06-21","2023-06-24","2023-06-27","2023-06-30","2023-06-08","2023-06-15","2023-06-22","2023-07-03","2023-06-15","2023-06-30"] },
// ], id: -1660944376, rootId: -1660944376, totalRows: 18 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1660944376) });
//
//
//         </script>
//         </html>

// %%
fun LocalDate.showAs(pattern: String) : String = this.format(DateTimeFormatter.ofPattern(pattern))
fun LocalDate.showAsOrAbbr(pattern: String, maximumMonthLetters: Int) : String =
    (if (this.showAs("MMMM").length > maximumMonthLetters) pattern.replace("MMMM", "MMM.") else pattern).let { this.showAs(it) }
fun areSameMonth(firstDate: LocalDate, secondDate: LocalDate) : Boolean = (firstDate.month == secondDate.month && firstDate.year == secondDate.year)

fun createReadableDateRange(startDate: LocalDate, endDate: LocalDate, maximumMonthLetters: Int = 12) : String =
    when {
        areSameMonth(startDate, endDate) -> listOf<String>(
                                                startDate.showAsOrAbbr("MMMM d", maximumMonthLetters),
                                                endDate.showAs("d, yyyy")
                                            ).joinToString("-")
        else -> "${startDate.showAs("MMM. d")} to ${endDate.showAs("MMM. d, yyyy")}"
    }


data class OfferCalendar(
    val OfferMonth: LocalDate,
    val CalendarName: String,
    val Period: Int,
    val StartDate: LocalDate,
    val EndDate: LocalDate
)

fun OfferCalendar.readableRange(maxMonthLetters: Int) = createReadableDateRange(StartDate, EndDate, maxMonthLetters)
fun OfferCalendar.types() = when {
    CalendarName.contains("All") -> listOf("gaming", "dining", "hotel")
    CalendarName.contains("Hotel") -> listOf("hotel")
    CalendarName.contains("Gaming") -> listOf("gaming")
    CalendarName.contains("Dining") -> listOf("dining")
    else -> listOf()
}

// %%
val calendarList : List<OfferCalendar> = dfCalendars.toListOf<OfferCalendar>()
calendarList
// Out:
// [OfferCalendar(OfferMonth=2023-06-01, CalendarName=HotelCalendar, Period=1, StartDate=2023-06-01, EndDate=2023-06-15), OfferCalendar(OfferMonth=2023-06-01, CalendarName=HotelCalendar, Period=2, StartDate=2023-06-16, EndDate=2023-06-30), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=1, StartDate=2023-06-01, EndDate=2023-06-03), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=2, StartDate=2023-06-04, EndDate=2023-06-06), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=3, StartDate=2023-06-07, EndDate=2023-06-09), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=4, StartDate=2023-06-10, EndDate=2023-06-12), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=5, StartDate=2023-06-13, EndDate=2023-06-15), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=6, StartDate=2023-06-16, EndDate=2023-06-18), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=7, StartDate=2023-06-19, EndDate=2023-06-21), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=8, StartDate=2023-06-22, EndDate=2023-06-24), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=9, StartDate=2023-06-25, EndDate=2023-06-27), OfferCalendar(OfferMonth=2023-06-01, CalendarName=GamingCalendar, Period=10, StartDate=2023-06-28, EndDate=2023-06-30), OfferCalendar(OfferMonth=2023-06-01, CalendarName=DiningCalendar, Period=1, StartDate=2023-06-01, EndDate=2023-06-08), OfferCalendar(OfferMonth=2023-06-01, CalendarName=DiningCalendar, Period=2, StartDate=2023-06-09, EndDate=2023-06-15), OfferCalendar(OfferMonth=2023-06-01, CalendarName=DiningCalendar, Period=3, StartDate=2023-06-16, EndDate=2023-06-22), OfferCalendar(OfferMonth=2023-06-01, CalendarName=DiningCalendar, Period=4, StartDate=2023-06-23, EndDate=2023-07-03), OfferCalendar(OfferMonth=2023-06-01, CalendarName=CalGeoAllCalendar, Period=1, StartDate=2023-06-01, EndDate=2023-06-15), OfferCalendar(OfferMonth=2023-06-01, CalendarName=CalGeoAllCalendar, Period=2, StartDate=2023-06-16, EndDate=2023-06-30)]

// %%
val ValidDates by column<List<OfferCalendar>>()
val ValidDateStrings by column<List<String>>()

val dfTieredOffersAndDates = dfTieredOffersPlusHotel
    // we got to here in an earlier cell
    // now we're going to bring in OfferCalendar objects, and assign a list of them (based on geo) to each tier
    .add(ValidDates) { dfCalendars.filter { when {
                                                    Tier <= 1999 -> !CalendarName.contains("Geo")
                                                    Tier >= 2000 -> CalendarName.startsWith("CalGeo")
                                                    else -> true
                                                } }.toListOf<OfferCalendar>() }
    // filter each specific type of OfferCalendar objects into their own columns (each contains a list)
    .add {
        "HotelOffers" from ValidDates.map { it.filter { it.types().contains("hotel") } }
        "GamingOffers" from ValidDates.map { it.filter { it.types().contains("gaming") } }
        "DiningOffers" from ValidDates.map { it.filter { it.types().contains("dining") } }
    }
    // split the lists so each element is in its own column
    .split { "HotelOffers"<List<OfferCalendar>>() }.into { it -> "hotel$it" }
    .split { "GamingOffers"<List<OfferCalendar>>() }.into { it -> "gaming$it" }
    .split { "DiningOffers"<List<OfferCalendar>>() }.into { it -> "dining$it" }
    .remove { ValidDates }
    // now convert the OfferCalendar objects to the string representation of date range
    // don't forget the ? - some columns contain null values because lists were not all same size
    .convert { colsOf<OfferCalendar?>() }.with { it?.readableRange(5) ?: "" }
    
    
dfTieredOffersAndDates
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944375"></table>
//
// <p class="dataframe_description">... showing only top 20 of 32 rows</p><p class="dataframe_description">DataFrame: rowsCount = 32, columnsCount = 33</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Tier: Int\">Tier</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1003</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1004</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1005</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1006</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2002</span></span>"] },
// { name: "<span title=\"GamePref: String\">GamePref</span>", children: [], rightAlign: false, values: ["Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table","Slot","Table"] },
// { name: "<span title=\"OutsideHeadline: String\">OutsideHeadline</span>", children: [], rightAlign: false, values: ["10 JUNE OFFERS WORTH $4,400 INSIDE!","10 JUNE OFFERS WORTH $3,400 INSIDE!","10 JUNE OFFERS WORTH $2,240 INSIDE!","10 JUNE OFFERS WORTH $1,740 INSIDE!","10 JUNE OFFERS WORTH $1,160 INSIDE!","10 JUNE OFFERS WORTH $910 INSIDE!","10 JUNE OFFERS WORTH $620 INSIDE!","10 JUNE OFFERS WORTH $570 INSIDE!","10 JUNE OFFERS WORTH $480 INSIDE!","10 JUNE OFFERS WORTH $380 INSIDE!","10 JUNE OFFERS WORTH $360 INSIDE!","10 JUNE OFFERS WORTH $360 INSIDE!","10 JUNE OFFERS WORTH $240 INSIDE!","10 JUNE OFFERS WORTH $240 INSIDE!","10 JUNE OFFERS WORTH $178 INSIDE!","10 JUNE OFFERS WORTH $128 INSIDE!","<span class=\"formatted\" title=\"GET UP TO $2,800 WHEN YOU VISIT US IN JUNE!\">GET UP TO $2,800 WHEN YOU VISIT US IN<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"GET UP TO $3,600 WHEN YOU VISIT US IN JUNE!\">GET UP TO $3,600 WHEN YOU VISIT US IN<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"GET UP TO $1,500 WHEN YOU VISIT US IN JUNE!\">GET UP TO $1,500 WHEN YOU VISIT US IN<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"GET UP TO $1,800 WHEN YOU VISIT US IN JUNE!\">GET UP TO $1,800 WHEN YOU VISIT US IN<span class=\"structural\">...</span></span>"] },
// { name: "<span title=\"HotelHeadline: String\">HotelHeadline</span>", children: [], rightAlign: false, values: ["2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","2 NIGHT STAY-CATION","1 NIGHT STAY-CATION","1 NIGHT STAY-CATION","1 NIGHT STAY-CATION","1 NIGHT STAY-CATION","RATES STARTING AT $39","RATES STARTING AT $39","RATES STARTING AT $39","RATES STARTING AT $39","3 NIGHTS IN A SUITE","3 NIGHTS IN A SUITE","3 NIGHTS IN A SUITE","3 NIGHTS IN A SUITE"] },
// { name: "<span title=\"HotelDescription: String\">HotelDescription</span>", children: [], rightAlign: false, values: ["<span class=\"form

// %%
val dfPlayerOffers = dfPlayers
    .sortBy { Tier and GamePref and PlayerID } 
    .update { Email }.with { it?.lowercase()?.trim() ?: "" }
    .remove { EvaluationDate and ExclusionCode and Mailing and Geo and ADT and Measure }
    .innerJoin(dfTieredOffersAndDates) { Tier and GamePref }
    .move { Tier and GamePref  }.after { OfferMonth }
    .convert { Birthday }.with { Birthday.month == OfferMonth.month }
    .remove("OfferMonth1")
    
dfPlayerOffers
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1660944374"></table>
//
// <p class="dataframe_description">... showing only top 20 of 914 rows</p><p class="dataframe_description">DataFrame: rowsCount = 914, columnsCount = 43</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"OfferMonth: kotlinx.datetime.LocalDate\">OfferMonth</span>", children: [], rightAlign: false, values: ["2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01","2023-06-01"] },
// { name: "<span title=\"Tier: Int\">Tier</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1001</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1002</span></span>"] },
// { name: "<span title=\"GamePref: String\">GamePref</span>", children: [], rightAlign: false, values: ["Slot","Slot","Slot","Slot","Slot","Slot","Slot","Slot","Table","Table","Table","Table","Table","Slot","Slot","Slot","Slot","Slot","Slot","Slot"] },
// { name: "<span title=\"PlayerID: Long\">PlayerID</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">10142332</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10417607</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">44418281</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">85435467</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">101520524</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">232721698</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">918262094</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2000257319</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10247877</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10513718</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">217959636</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">436671431</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">952558332</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10418502</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">283858991</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">419498860</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">466237510</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">620983164</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">743915907</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">939288419</span></span>"] },
// { name: "<span title=\"FirstName: String\">FirstName</span>", children: [], rightAlign: false, values: ["Sh****","Ti**","Ro****","Na*","Li***","Je*****","Ho****","Ka***","Ji*****","Bi***","Xi*","Qi*","Ja***","Ja***","Ch*****","St*

// %%
dfPlayerOffers
    .remove { Email and Birthday and 
                GamingAmount and GamingFrequency and DiningAmount and DiningFrequency and HotelFrequency }
    .writeCSV("MailFile.csv", CSVFormat.DEFAULT.withDelimiter(';'))
    
dfPlayerOffers
    .filter { Email.contains("@") }
    .remove { Address and City and State and Country and ZipCode and 
                GamingAmount and GamingFrequency and DiningAmount and DiningFrequency and HotelFrequency }
    .writeCSV("EmailFile.csv", CSVFormat.DEFAULT.withDelimiter(';'))

// %%
dfPlayerOffers.size()
// Out:
// 914 x 43
